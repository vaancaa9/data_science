# %%
api_key="AIzaSyBckCT6gJvyoY-hu9BIkDxoio4BApY-kfQ"

# %%
api_service_name = "youtube"
api_version = "v3"

# %%
youtube = build(
        api_service_name, api_version, developerKey=api_key)

request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        forUsername="GoogleDevelopers"
    )
response = request.execute()

pprint(response["items"][0])

# %%
channel_name= response["items"][0]["snippet"]["title"]
Channel_description=response["items"][0]["snippet"]["description"]
Channel_PublishedAt=response["items"][0]["snippet"]["publishedAt"]
Channel_contentDetails=response["items"][0]["contentDetails"]
Channel_subcriberCount=response["items"][0]["statistics"]['subscriberCount']
Channel_VideoCount=response["items"][0]["statistics"]["videoCount"]
Channel_ViewCount=response["items"][0]["statistics"]["viewCount"]
Channel_Playlists=response["items"][0]["contentDetails"]["relatedPlaylists"]

# %%
Channel_informations = { 'Channel_title' : response["items"][0]["snippet"]["title"],
                        'Channel_description' : response["items"][0]["snippet"]["description"],
                        'Channel_PublishedAt' : response["items"][0]["snippet"]["publishedAt"],
                        'Channel_contentDetails' : response["items"][0]["contentDetails"],
                        'Channel_subcriberCount' : response["items"][0]["statistics"]['subscriberCount'],
                        'Channel_VideoCount' : response["items"][0]["statistics"]["videoCount"],
                        'Channel_ViewCount' : response["items"][0]["statistics"]["viewCount"],
                        'Channel_Playlists' : response["items"][0]["contentDetails"]["relatedPlaylists"] }

pprint(Channel_informations)
# Out:
# {'Channel_Playlists': {'likes': '', 'uploads': 'UU_x5XG1OV2P6uZZ5FSM9Ttw'},
#  'Channel_PublishedAt': '2007-08-23T00:34:43Z',
#  'Channel_VideoCount': '5926',
#  'Channel_ViewCount': '236844726',
#  'Channel_contentDetails': {'relatedPlaylists': {'likes': '',
#                                                  'uploads': 'UU_x5XG1OV2P6uZZ5FSM9Ttw'}},
#  'Channel_description': 'Subscribe to join a community of creative developers '
#                         'and learn the latest in Google technology — from AI '
#                         'and cloud, to mobile and web.\n'
#                         '\n'
#                         'Explore more at developers.google.com\n'
#                         '\n',
#  'Channel_subcriberCount': '2330000',
#  'Channel_title': 'Google for Developers'}

# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyBckCT6gJvyoY-hu9BIkDxoio4BApY-kfQ'
youtube = build('youtube', 'v3', developerKey=api_key)

request = youtube.channels().list(
   part="snippet,contentDetails,statistics",
   forUsername="BeautyWithin"
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'RuuXzTIr0OoDqI4S0RU6n4FqKEM', 'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}

# %%
from pprint import pprint
#pprint = pprint.PrettyPrinter(indent=4)

api_key="AIzaSyBckCT6gJvyoY-hu9BIkDxoio4BApY-kfQ"

api_service_name = "youtube"
api_version = "v3"

import googleapiclient.discovery

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=api_key)

request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id="UC_x5XG1OV2P6uZZ5FSM9Ttw,UCZERpBw5pNeklHCxT1wX7Cw,UCBwhzZv6UBDcqHU7RypKV-g,UC9mBD9wJ-QTjz6DbmbScaPg,UCNYaxPiba3oxmeL_3jKxnYA,UCxD03AhBg9LWQuJfijnzhhQ,UCnSXdCNbGIrWH0l1yC3YULw,UCkBFs3_HFySYZZvwuYegIOg,UCSMtl5UvvJOMkFnMrjNCrtA,UCKUHl9qrizvt_cfldeVXuyw"
)
response = request.execute()

pprint(response)
# Out:
# {'etag': 'I9sjJAKUBFz3C_bXz_4iqWy6LMs',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUBwhzZv6UBDcqHU7RypKV-g'}},
#             'etag': 'Pv3K9StuO0-TfSVusYpOboo4Bkw',
#             'id': 'UCBwhzZv6UBDcqHU7RypKV-g',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'IN',
#                         'customUrl': '@yummycooking-pjr',
#                         'defaultLanguage': 'ta',
#                         'description': 'Welcome to YUMMY COOKING, I am '
#                                        'homemaker , I enjoyed cooking from my '
#                                        'childhood. \n'
#                                        'I used to watch my mom cooking and I '
#                                        'always made recipes when ever i have '
#                                        'the time.\n'
# ...

# %%
channel_name= response["items"][0]["snippet"]["title"]
Channel_description=response["items"][0]["snippet"]["description"]
Channel_PublishedAt=response["items"][0]["snippet"]["publishedAt"]
Channel_contentDetails=response["items"][0]["contentDetails"]
Channel_subcriberCount=response["items"][0]["statistics"]['subscriberCount']
Channel_VideoCount=response["items"][0]["statistics"]["videoCount"]
Channel_ViewCount=response["items"][0]["statistics"]["viewCount"]
Channel_Playlists=response["items"][0]["contentDetails"]["relatedPlaylists"]

# %%
Channel_informations = { 'channel_name' : response["items"][0]["snippet"]["title"],
                         'Channel_description' : response["items"][0]["snippet"]["description"],
                         'Channel_PublishedAt' : response["items"][0]["snippet"]["publishedAt"],
                         'Channel_contentDetails' : response["items"][0]["contentDetails"],
                         'Channel_subcriberCount' : response["items"][0]["statistics"]['subscriberCount'],
                         'Channel_VideoCount' : response["items"][0]["statistics"]["videoCount"],
                         'Channel_ViewCount'  : response["items"][0]["statistics"]["viewCount"],
                         'Channel_Playlists' : response["items"][0]["contentDetails"]["relatedPlaylists"] }

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client['Youtube']
collection = db['Channel_data']

collection.insert_one(data)
#data = {
 #  'channel_name': channel_name,
  # 'subscriber_count': subscriber_count,
   #'video_count': video_count
#}

#collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6577ec8419732a297c7c9894'), acknowledged=True)

# %%
data = {
   'channel_name': channel_name,
   'subscriber_count': subscriber_count,
   'video_count': video_count
}

collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6577626619732a297c7c9888'), acknowledged=True)

# %%
from pprint import pprint
#pprint = pprint.PrettyPrinter(indent=4)

api_key="AIzaSyBckCT6gJvyoY-hu9BIkDxoio4BApY-kfQ"

api_service_name = "youtube"
api_version = "v3"

import googleapiclient.discovery

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=api_key)


client = MongoClient('mongodb://localhost:27017/')
db = client['Youtube']
collection = db['Channel_data']


channel_ids = ['UC_x5XG1OV2P6uZZ5FSM9Ttw','UCZERpBw5pNeklHCxT1wX7Cw','UCBwhzZv6UBDcqHU7RypKV-g','UC9mBD9wJ-QTjz6DbmbScaPg','UCNYaxPiba3oxmeL_3jKxnYA','UCxD03AhBg9LWQuJfijnzhhQ','UCnSXdCNbGIrWH0l1yC3YULw','UCkBFs3_HFySYZZvwuYegIOg','UCSMtl5UvvJOMkFnMrjNCrtA','UCKUHl9qrizvt_cfldeVXuyw']

for channel_id in channel_ids:
   request = youtube.channels().list(
       part="snippet,contentDetails,statistics",
       id=channel_id
   )
response = request.execute()

channel = response['items'][0]
#channel_name = channel['snippet']['title']
subscriber_count = channel['statistics']['subscriberCount']
video_count = channel['statistics']['videoCount']

data = {
       'channel_name': channel_name,
       'subscriber_count': subscriber_count,
       'video_count': video_count
}

collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('65782a6719732a297c7c98d6'), acknowledged=True)

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client['Youtube']
collection = db['Channel_data']

channel_ids=["UC_x5XG1OV2P6uZZ5FSM9Ttw","UCZERpBw5pNeklHCxT1wX7Cw","UCBwhzZv6UBDcqHU7RypKV-g","UC9mBD9wJ-QTjz6DbmbScaPg","UCNYaxPiba3oxmeL_3jKxnYA","UCxD03AhBg9LWQuJfijnzhhQ","UCnSXdCNbGIrWH0l1yC3YULw","UCkBFs3_HFySYZZvwuYegIOg","UCSMtl5UvvJOMkFnMrjNCrtA","UCKUHl9qrizvt_cfldeVXuyw"]


for channel_id in channel_ids:
   request = youtube.channels().list(
       part="snippet,contentDetails,statistics",
       id=channel_id
   )
   response = request.execute()

   channel = response['items'][0]
   channel_name = channel['snippet']['title']
   subscriber_count = channel['statistics']['subscriberCount']
   video_count = channel['statistics']['videoCount']

   data = {
       'channel_name': channel_name,
       'subscriber_count': subscriber_count,
       'video_count': video_count
   }

   collection.insert_one(data)

# %%
from pymongo import MongoClient
from bson import ObjectId
from sqlalchemy import create_engine, text

# Connect to MySQL database
engine = create_engine("mysql+mysqlconnector://root:Omomom%40999@localhost/youtube_channels")

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
mongodb = client['Youtube']
collection = mongodb['Channel_data']

# # Prepare data to insert into MySQL
values = []

for abc in collection.find():
    uids = str(abc.get("_id"))  # Convert ObjectId to string
    channel_name = abc.get("channel_name")
    subscriber_count = abc.get("subscriber_count")
    video_count = abc.get("video_count")

    # Construct a tuple for each set of values and append to the list
    data_tuple = (uids, channel_name, subscriber_count, video_count)
    values.append(data_tuple)

cursor = collection.find()
#print(values)


   
import MySQLdb

def mysqlconnect():
    db_connection= None
    #Trying to connect 
    try:
        db_connection= MySQLdb.connect
        ("localhost","root","Omomom@999","youtube_channels")
    # If connection is not successful
    except:
        print("Can't connect to database")
        return 0
    # If Connection Is Successful
    print("Connected")


connection= MySQLdb.connect("localhost","root","Omomom@999","youtube_channels")

cursor1 = connection.cursor()
i=1
for abc in values:
    uids= abc[0]
    channel_name=abc[1]
    subscriber_count=abc[2]

    video_count=abc[3]
    i+=1

    sql = "INSERT INTO youtube_data (channel_id, channel_name, subscriber_count, video_count) VALUES (%s, %s, %s, %s)"
    cursor1.execute(sql, (uids, channel_name, subscriber_count, video_count))
connection.commit()
connection.close()

# mysqlconnect()
